# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Lire le fichier .csv
dataFrame = pd.read_csv('Car_Price_Prediction.csv')
dataFrame
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
###Preprocessing
#Supprimer les lignes qui contiennent des valeurs manquantes
dataFrame = dataFrame.dropna()
dataFrame
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
#Afficher l'en-tête du dataset
dataFrame.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#Afficher le pied du dataset
dataFrame.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
#Statistiques rapides du dataset
dataFrame.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#Informations sur le dataset
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#Afficher l'occurence des colonnes qui ont des valeurs nulles
dataFrame.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#Diviser la colonne de CarName en manufacturer et modelName pour une meilleure visibilité
dataFrame[['manufacturer', 'modelName']] = dataFrame.CarName.str.split(" ",n=1, expand=True)

#Changer l'emplacement des colonnes manufacturer et modelName
colonneManufacturer = dataFrame.pop('manufacturer')
dataFrame.insert(2, 'manufacturer', colonneManufacturer)

colonneModelName = dataFrame.pop('modelName')
dataFrame.insert(3, 'modelName', colonneModelName)

#Supprimer la colonne de CarName (l'ancienne colonne)
dataFrame.drop(['CarName'], axis=1, inplace=True)
# Out:
#      car_ID  symboling manufacturer     modelName fueltype aspiration  \
# 0         1          3  alfa-romero        giulia      gas        std
# 1         2          3  alfa-romero       stelvio      gas        std
# 2         3          1  alfa-romero  Quadrifoglio      gas        std
# 3         4          2         audi        100 ls      gas        std
# 4         5          2         audi         100ls      gas        std
# ..      ...        ...          ...           ...      ...        ...
# 200     201         -1        volvo     145e (sw)      gas        std
# 201     202         -1        volvo         144ea      gas      turbo
# 202     203         -1        volvo         244dl      gas        std
# 203     204         -1        volvo           246   diesel      turbo
# 204     205         -1        volvo         264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  ...  enginesize  \
# ...

# %%
# Out:
#      car_ID  symboling manufacturer     modelName                   CarName  \
# 0         1          3  alfa-romero        giulia        alfa-romero giulia
# 1         2          3  alfa-romero       stelvio       alfa-romero stelvio
# 2         3          1  alfa-romero  Quadrifoglio  alfa-romero Quadrifoglio
# 3         4          2         audi        100 ls               audi 100 ls
# 4         5          2         audi         100ls                audi 100ls
# ..      ...        ...          ...           ...                       ...
# 200     201         -1        volvo     145e (sw)           volvo 145e (sw)
# 201     202         -1        volvo         144ea               volvo 144ea
# 202     203         -1        volvo         244dl               volvo 244dl
# 203     204         -1        volvo           246                 volvo 246
# 204     205         -1        volvo         264gl               volvo 264gl
#
# ...

# %%
#L'affichage de l'en-tête du dataset
dataFrame.head()
# Out:
#    car_ID  symboling manufacturer     modelName fueltype aspiration  \
# 0       1          3  alfa-romero        giulia      gas        std
# 1       2          3  alfa-romero       stelvio      gas        std
# 2       3          1  alfa-romero  Quadrifoglio      gas        std
# 3       4          2         audi        100 ls      gas        std
# 4       5          2         audi         100ls      gas        std
#
#   doornumber      carbody drivewheel enginelocation  ...  enginesize  \
# 0        two  convertible        rwd          front  ...         130
# 1        two  convertible        rwd          front  ...         130
# 2        two    hatchback        rwd          front  ...         152
# 3       four        sedan        fwd          front  ...         109
# 4       four        sedan        4wd          front  ...         136
#
#    fuelsystem  boreratio  stroke  compressionratio horsepower peakrpm  \
# ...

# %%
#L'affichage le pied du dataset
dataFrame.tail()
# Out:
#      car_ID  symboling manufacturer  modelName fueltype aspiration doornumber  \
# 200     201         -1        volvo  145e (sw)      gas        std       four
# 201     202         -1        volvo      144ea      gas      turbo       four
# 202     203         -1        volvo      244dl      gas        std       four
# 203     204         -1        volvo        246   diesel      turbo       four
# 204     205         -1        volvo      264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  ...  enginesize  fuelsystem  boreratio  \
# 200   sedan        rwd          front  ...         141        mpfi       3.78
# 201   sedan        rwd          front  ...         141        mpfi       3.78
# 202   sedan        rwd          front  ...         173        mpfi       3.58
# 203   sedan        rwd          front  ...         145         idi       3.01
# 204   sedan        rwd          front  ...         141        mpfi       3.78
#
# ...

# %%
#Correction des noms des constructeurs de véhicule
dataFrame['manufacturer'] = dataFrame['manufacturer'].str.lower()

#Définir la fonction de correction
def changeName(oldName, newName):
    dataFrame['manufacturer'].replace(oldName, newName, inplace=True)
    
#Appliquer la fonction
changeName('maxda','mazda')
changeName('porcshce','porsche')
changeName('toyouta','toyota')
changeName('vokswagen','volkswagen')
changeName('vw','volkswagen')

#Afficher la liste des constructeurs
dataFrame['manufacturer'].unique()
# Out:
#     manufacturer     modelName fueltype aspiration doornumber      carbody  \
# 0    alfa-romero        giulia      gas        std        two  convertible
# 1    alfa-romero       stelvio      gas        std        two  convertible
# 2    alfa-romero  Quadrifoglio      gas        std        two    hatchback
# 3           audi        100 ls      gas        std       four        sedan
# 4           audi         100ls      gas        std       four        sedan
# ..           ...           ...      ...        ...        ...          ...
# 200        volvo     145e (sw)      gas        std       four        sedan
# 201        volvo         144ea      gas      turbo       four        sedan
# 202        volvo         244dl      gas        std       four        sedan
# 203        volvo           246   diesel      turbo       four        sedan
# 204        volvo         264gl      gas      turbo       four        sedan
#
# ...

# %%
#La matrice de corrélation entre les variables
plt.figure(figsize=(15,8))
sns.heatmap(dataFrame.corr(), annot=True, cmap='coolwarm')
plt.title("Matrice de corrélation entre les features et la target", size=20)
plt.show()

# %%
#Supprimer les variables qui n'affectent pas la target variable soit positivemen ou negativement
dataFrame.drop(['car_ID', 'symboling', 'stroke', 'compressionratio', 'peakrpm'], axis=1, inplace=True)
dataFrame
# Out:
#     manufacturer     modelName fueltype aspiration doornumber      carbody  \
# 0    alfa-romero        giulia      gas        std        two  convertible
# 1    alfa-romero       stelvio      gas        std        two  convertible
# 2    alfa-romero  Quadrifoglio      gas        std        two    hatchback
# 3           audi        100 ls      gas        std       four        sedan
# 4           audi         100ls      gas        std       four        sedan
# ..           ...           ...      ...        ...        ...          ...
# 200        volvo     145e (sw)      gas        std       four        sedan
# 201        volvo         144ea      gas      turbo       four        sedan
# 202        volvo         244dl      gas        std       four        sedan
# 203        volvo           246   diesel      turbo       four        sedan
# 204        volvo         264gl      gas      turbo       four        sedan
#
# ...

# %%
#Afficher un tableau avec l'occurence de véhicules pour chaque constructeur
tableau = dataFrame['manufacturer'].value_counts().reset_index()
tableau.columns = ['Constructeur', 'Effectif']
tableau.T
# Out:
#                   0       1      2           3      4           5        6   \
# Constructeur  toyota  nissan  mazda  mitsubishi  honda  volkswagen  peugeot
# Effectif          32      18     17          13     13          12       11
#
#                  7       8      9   ...    12        13    14       15     16  \
# Constructeur  volvo  subaru  dodge  ...  audi  plymouth  saab  porsche  isuzu
# Effectif         11      10      9  ...     7         7     6        5      4
#
#                   17         18           19       20       21
# Constructeur  jaguar  chevrolet  alfa-romero  renault  mercury
# Effectif           3          3            3        2        1
#
# [2 rows x 22 columns]

# %%
#Vérifier le nom du modèle le plus populaire
model = dataFrame['modelName'].value_counts().reset_index()
model.columns = ['Nom du modèle', 'Effectif']

plt.figure(figsize=(15,8))
effectifModel = dataFrame['modelName'].value_counts()[0:10].sort_values(ascending=False)
sns.countplot(data=dataFrame, x='modelName', order=effectifModel.index,palette='mako')
plt.title('La fréquence du nom du modèle', size=20)
plt.xlabel('Modèle', size=13)
plt.ylabel('Fréquence', size=13)
plt.show()

# %%
#Vérifier le nom du constructeur le plus populaire
plt.figure(figsize=(15,8))
color = sns.color_palette('pastel')
plt.pie(tableau['Effectif'], colors=color, autopct='%.0f%%', labels=tableau["Constructeur"])
plt.show()

# %%
###Vérifier le type de carburant le plus populaire 
#Version tableau
tableauCarburant = dataFrame['fueltype'].value_counts().reset_index()
tableauCarburant.columns = ['Type de carburant', 'Effectif']
tableauCarburant
# Out:
#   Type de carburant  Effectif
# 0               gas       183
# 1            diesel        20

# %%
###Vérifier le type de carburant le plus populaire 
#Version graphe
plt.figure(figsize=(7,5))
modelCarburant = dataFrame['fueltype'].value_counts()[0:10].sort_values(ascending=False)
sns.countplot(data=dataFrame, x='fueltype', order=modelCarburant.index, palette='mako')
plt.title('La fréquene du type de carburant', size=20)
plt.xlabel('Type de carburant',size=13)
plt.ylabel('Fréquence',size=13)
plt.show()

# %%
###Vérifier le type de roue motrice le plus populaire
#Version tableau
tableauWheelDrive = dataFrame['drivewheel'].value_counts().reset_index()
tableauWheelDrive.columns = ['Type de roue motrice', 'Effectif']
tableauWheelDrive
# Out:
#   Type de roue motrice  Effectif
# 0                  fwd       118
# 1                  rwd        76
# 2                  4wd         9

# %%
###Vérifier le type de roue motrice le plus populaire
#Version graphe
plt.figure(figsize=(7,5))
modelWheelDrive = dataFrame['drivewheel'].value_counts()[0:10].sort_values(ascending=False)
sns.countplot(data=dataFrame, x='drivewheel', order=modelWheelDrive.index, palette='mako')
plt.title('La fréquene du type de roue motrice', size=20)
plt.xlabel('Type de roue motrice',size=13)
plt.ylabel('Fréquence',size=13)
plt.show()

# %%
###Vérifier le type de carrosserie le plus populaire
#Version tableau 
tableauCarrosserie = dataFrame['carbody'].value_counts().reset_index()
tableauCarrosserie.columns = ['Type de carrosserie', 'Effectif']
tableauCarrosserie
# Out:
#   Type de carrosserie  Effectif
# 0               sedan        95
# 1           hatchback        69
# 2               wagon        25
# 3             hardtop         8
# 4         convertible         6

# %%
###Vérifier le type de roue motrice le plus populaire
#Version graphe
plt.figure(figsize=(7,5))
modelCarrosserie = dataFrame['carbody'].value_counts()[0:10].sort_values(ascending=False)
sns.countplot(data=dataFrame, x='carbody', order=modelCarrosserie.index, palette='mako')
plt.title('La fréquene du type de carrosserie', size=20)
plt.xlabel('Type de carrosserie',size=13)
plt.ylabel('Fréquence',size=13)
plt.show()

# %%
###Vérifier si le type de carburant influence le prix de vente pour chaque construteur
#Version graphe
plt.figure(figsize=(15,8))
sns.barplot(x='manufacturer', y='price', data=dataFrame[0:10000], hue='fueltype', palette='mako')
plt.title("L'influence du type de carburant sur la vente de chaque compagnie", size=20)
plt.xlabel('Modèle', size=13)
plt.ylabel('Prix', size=13)
plt.xticks(rotation=45)
plt.show()

# %%
###Vérifier si le type de carburant influence le prix de vente pour chaque construteur
#Version tableau
influenceFuel = pd.DataFrame(dataFrame.groupby(['manufacturer',"fueltype"])['price'].mean().sort_values())
influenceFuel.reset_index()
# Out:
#    manufacturer fueltype         price
# 0     chevrolet      gas   6007.000000
# 1        nissan   diesel   7099.000000
# 2         dodge      gas   7875.444444
# 3      plymouth      gas   7963.428571
# 4         honda      gas   8184.692308
# 5        toyota   diesel   8794.666667
# 6         isuzu      gas   8916.500000
# 7        subaru      gas   9025.100000
# 8    mitsubishi      gas   9239.769231
# 9       renault      gas   9595.000000
# 10   volkswagen   diesel   9777.500000
# 11       toyota      gas   9998.689655
# 12        mazda      gas  10130.666667
# 13   volkswagen      gas  10227.500000
# 14       nissan      gas  10610.764706
# 15        mazda   diesel  14569.500000
# 16         saab      gas  15223.333333
# 17      peugeot      gas  15232.500000
# 18  alfa-romero      gas  15498.333333
# 19      peugeot   diesel  15797.000000
# 20      mercury      gas  16503.000000
# 21        volvo      gas  17622.500000
# 22         audi      gas  17859.166714
# ...

# %%
###La moyenne des prix pour chaque compagnie
#Version tableau
moyennePrix = pd.DataFrame(dataFrame.groupby(['manufacturer'])['price'].mean().sort_values(ascending=False))
moyennePrix.reset_index()
# Out:
#    manufacturer         price
# 0        jaguar  34600.000000
# 1         buick  33647.000000
# 2       porsche  31400.500000
# 3           bmw  26118.750000
# 4         volvo  18063.181818
# 5          audi  17859.166714
# 6       mercury  16503.000000
# 7   alfa-romero  15498.333333
# 8       peugeot  15489.090909
# 9          saab  15223.333333
# 10        mazda  10652.882353
# 11       nissan  10415.666667
# 12   volkswagen  10077.500000
# 13       toyota   9885.812500
# 14      renault   9595.000000
# 15   mitsubishi   9239.769231
# 16       subaru   9025.100000
# 17        isuzu   8916.500000
# 18        honda   8184.692308
# 19     plymouth   7963.428571
# 20        dodge   7875.444444
# 21    chevrolet   6007.000000

# %%
###La moyenne des prix pour chaque compagnie
#Version graphe
plt.figure(figsize=(20,6))
moyennePrix.plot.bar()
plt.title("La moyenne des prix pour chaque constructeur", size=20)
plt.xlabel("Constructeur",size=13)
plt.ylabel("Moyenne des prix" , size=13)
plt.show()

# %%
###Le modèle d'apprentissage
#Importation des bibliothèques
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV,RidgeCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor , AdaBoostRegressor ,GradientBoostingRegressor 
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
#Le dataFrame des features
X = dataFrame.drop('price', axis=1)
#Le dataFrame du target
y = dataFrame['price']

# %%
#Encodage des valeurs non numériques
columnsNaN = [column for column in X if X[column].dtype=='object'] #Les colonnes contenant les valeurs non numériques
X = pd.get_dummies(X, columns=columnsNaN, drop_first=True)

scaling = StandardScaler()
X = scaling.fit_transform(X)
X = pd.DataFrame(X)

# %%
#Diviser le dataSet des features et du target en test_set et en train_set
X_train,X_test,y_train,y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
#Afficher la taille de X_train, X_test, y_train, y_test
print("X_train shape: ",X_train.shape)
print("X_test shape: ",X_test.shape)
print("Y_train shape: ",y_train.shape)
print("Y_test shape: ",y_test.shape)
# Out:
# X_train shape:  (164, 190)
# X_test shape:  (41, 190)
# Y_train shape:  (164,)
# Y_test shape:  (41,)

# %%
#Afficher les performaances de chaque modèle
#Définition de la fonction de calcul de performance
def evaluerModel(model):
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test) 
    
    #Afficher les caractéristiques de chaque modèle
    print("Nom du modèle: ",model)
    print("Score du modèle : "+str(model.score(X_test, y_test) * 100))
    print("MSE : ",mean_squared_error(y_test,y_pred))
    print("MAE : ",mean_absolute_error(y_test,y_pred))
    print("-------------------------------------------------------------")

# %%
#Initialisation des modèles
linearRegression = LinearRegression()
lasso = LassoCV()
ridge = RidgeCV() 
knn = KNeighborsRegressor() 
svr = SVR()
decisionTreeRegressor = DecisionTreeRegressor()

randomForestRegressor = RandomForestRegressor(n_estimators=200,random_state=42)
ada = AdaBoostRegressor(random_state=42)
gbr = GradientBoostingRegressor(random_state=42)

#La liste des modèles
listModels = [linearRegression, lasso, ridge, knn, svr, decisionTreeRegressor, randomForestRegressor, ada, gbr]

#Afficher les performances de chaque modèle
for model in listModels:
    evaluerModel(model)
# Out:
# Nom du modèle:  LinearRegression()
# Score du modèle : -6.084630038085245e+26
# MSE :  4.803451607715938e+32
# MAE :  1.0881373226490148e+16
# -------------------------------------------------------------
# Nom du modèle:  LassoCV()
# Score du modèle : 81.4356795536708
# MSE :  14655421.009316692
# MAE :  2342.996386407242
# -------------------------------------------------------------
# Nom du modèle:  RidgeCV(alphas=array([ 0.1,  1. , 10. ]))
# Score du modèle : 77.95545803580434
# MSE :  17402847.811039522
# MAE :  2584.0828163901883
# -------------------------------------------------------------
# Nom du modèle:  KNeighborsRegressor()
# Score du modèle : 11.139026832798372
# MSE :  70150425.21098267
# MAE :  4547.426024390244
# -------------------------------------------------------------
# Nom du modèle:  SVR()
# Score du modèle : -10.206782129691705
# MSE :  87001665.09526266
# MAE :  5707.022237133275
# -------------------------------------------------------------
# ...

# %%
#Regrouper les modèles dans un dataframe
dataFrameModels = pd.DataFrame([
                                ,["LassoCV",str(lasso.score(X_test, y_test) * 100)]
                                ,["RidgeCV",str(ridge.score(X_test, y_test) * 100)]
                                ,["KNeighborsRegressor",str(knn.score(X_test, y_test) * 100)]
                                ,["SVR",str(svr.score(X_test, y_test) * 100)]
                                ,["DecisionTreeRegressor",str(decisionTreeRegressor.score(X_test, y_test) * 100)]
                                ,["RandomForestRegressor",str(randomForestRegressor.score(X_test, y_test) * 100)]
                                ,["AdaBoostRegressor",str(ada.score(X_test, y_test) * 100)]
                                ,["GradientBoostingRegressor",str(gbr.score(X_test, y_test) * 100)]
    
                               ]
                               ,columns=["models","accuracy"])
dataFrameModels
# Out:
#                       models             accuracy
# 0                    LassoCV     81.4356795536708
# 1                    RidgeCV    77.95545803580434
# 2        KNeighborsRegressor   11.139026832798372
# 3                        SVR  -10.206782129691705
# 4      DecisionTreeRegressor    86.55838062075615
# 5      RandomForestRegressor    95.51809727802113
# 6          AdaBoostRegressor     90.2297120082706
# 7  GradientBoostingRegressor    93.15610059339122

# %%
#Afficher les performances des modèles : version graphe
e = pd.DataFrame(dataFrameModels.groupby('models')['accuracy'].mean())
e.plot.bar(title='La précision de chaque modèle')
plt.xlabel("models")
plt.ylabel("accuracy")
plt.grid(linestyle='-.')
